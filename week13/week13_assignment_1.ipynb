# %% [markdown]
# # Week 13 Review Assignmnet
#
# For the questions below, we're going to refer exclusively to an HHCAPS survey data set that is available in `/data/hhcaps.csv`.  Use whatever commands you want to calculate the information required to get to the answer.  Then, enter your answer in the answers cell as usual.
#
# **NOTE: Enter your answers as string values (inside quotation marks "") even if the answer is actually numeric.**
#
# ---
# ---

# %%
# %matplotlib inline
import pandas as pd

hhcaps = pd.read_csv('/data/hhcaps.csv')

# %% [markdown]
# ## #01 -
#
# How many columns does this file contain?

# %%
# Write some code to figure it out
# Calculate the length of the list generated by .columns 
len(hhcaps.columns)
# Out:
# 39

# %%
answers={}
answers['40.1'] = "39"

# %% [markdown]
# ## #02 -
#
# How many different values for State are there in this file?

# %%
# Write some code to figure it out
# Determine which column might have State information
hhcaps.columns
# Out:
# Index(['State', 'CMS Certification Number (CCN)*', 'Provider Name', 'Address',
#        'City', 'Zip', 'Phone', 'Type of Ownership',
#        'Offers Nursing Care Services', 'Offers Physical Therapy Services',
#        'Offers Occupational Therapy Services',
#        'Offers Speech Pathology Services', 'Offers Medical Social Services',
#        'Offers Home Health Aide Services', 'Date Certified',
#        'HHCAHPS Survey Summary Star Rating',
#        'Footnote HHCAHPS Survey Summary Star Rating',
#        'Star Rating for health team gave care in a professional way',
#        'Footnote for Star Rating for gave care in a professional way',
#        'Percent of patients who reported that their home health team gave care in a professional way',
#        'Footnote for percent of patients who reported that their home health team gave care in a professional way',
#        'Star Rating for health team communicated well with them',
#        'Footnote for Star Rating for communicated well with them',
#        'Percent of patients who reported that their home health team communicated well with them',
#        'Footnote for percent of patients who reported that their home health team communicated well with them',
#        'Star Rating team discussed medicines, pain, and home safety',
#        'Footnote Star Rating discussed medicines, pain, home safety',
#        'Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them',
#        'Footnote for percent of patients who reported that their home health team discussed medicines, pain, and home safety with them',
#        'Star Rating for how patients rated overall care from agency',
#        'Footnote for Star Rating for overall care from agency',
#        'Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
#        'Footnote for percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)',
#        'Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family',
#        'Footnote for percent of patients who reported YES, they would definitely recommend the home health agency to friends and family',
#        'Number of completed Surveys',
#        'Footnote for number of completed surveys', 'Response rate',
#        'Footnote for response rate'],
#       dtype='object')

# %%
# Calculate the length of the list generated by value_counts
len(hhcaps['State'].value_counts())
# Out:
# 55

# %%
answers['40.2'] = "55"

# %% [markdown]
# ## #03 -
#
# Which of those State values has the highest frequency of occurence?

# %%
# Write some code to figure it out
# Use Value Counts to determine the frequencies of each State 
hhcaps['State'].value_counts()
# Out:
# TX    2518
# CA    1319
# FL    1069
# OH     781
# IL     735
# MI     597
# PA     425
# MA     261
# OK     256
# VA     244
# IN     229
# MN     197
# LA     195
# CO     187
# NC     174
# AR     172
# MO     169
# AZ     169
# IA     163
# AL     152
# NV     143
# NY     141
# TN     140
# WI     119
# KS     117
# GA     106
# KY     104
# UT      98
# CT      91
# NM      77
# NE      75
# SC      70
# WA      63
# WV      61
# OR      57
# MD      53
# MS      48
# NJ      47
# ID      45
# PR      45
# SD      33
# NH      31
# DC      28
# RI      27
# MT      27
# DE      26
# WY      26
# ME      24
# ND      18
# HI      16
# AK      14
# VT      11
# GU       4
# MP       2
# VI       1
# Name: State, dtype: int64

# %%
answers['40.3'] = "TX"

# %% [markdown]
# ## #04 -
#
# Which of those State values has the best average performance on the `Star Rating for health team communicated well with them` score?

# %%
# Write some code to figure it out
# Group the data by state
hhcaps_state = hhcaps.groupby('State')

# %%
# Aggregate the data for the requested column and determine the greatest value
hhcaps_state['Star Rating for health team communicated well with them'].mean().max()
# Out:
# 4.65

# %%
# Find the state corresponding to that value
hhcaps_state['Star Rating for health team communicated well with them'].mean() == 4.65
# Out:
# State
# AK    False
# AL    False
# AR    False
# AZ    False
# CA    False
# CO    False
# CT    False
# DC    False
# DE    False
# FL    False
# GA    False
# GU    False
# HI    False
# IA    False
# ID    False
# IL    False
# IN    False
# KS    False
# KY    False
# LA    False
# MA    False
# MD    False
# ME     True
# MI    False
# MN    False
# MO    False
# MP    False
# MS    False
# MT    False
# NC    False
# ND    False
# NE    False
# NH    False
# NJ    False
# NM    False
# NV    False
# NY    False
# OH    False
# OK    False
# OR    False
# PA    False
# PR    False
# RI    False
# SC    False
# SD    False
# TN    False
# TX    False
# UT    False
# VA    False
# VI    False
# VT    False
# WA    False
# WI    False
# WV    False
# WY    False
# Name: Star Rating for health team communicated well with them, dtype: bool

# %%
answers['40.4'] = "ME"

# %% [markdown]
# ## #05 -
#
# What was the average score on `Star Rating for how patients rated overall care from agency` for providers listed as having a `Type of Ownership` of `Hospital Based Program`
#
# **NOTE: Enter your answer with two decimal precision: 0.00**

# %%
# Write some code to figure it out
# Create a filter for type of ownership
own_filter = hhcaps['Type of Ownership'] == 'Hospital Based Program'

# Filter the data
hhcaps_filtered = hhcaps[own_filter]

# %%
# Check the filter
hhcaps_filtered['Type of Ownership'].head()
# Out:
# 35    Hospital Based Program
# 43    Hospital Based Program
# 49    Hospital Based Program
# 51    Hospital Based Program
# 52    Hospital Based Program
# Name: Type of Ownership, dtype: object

# %%
# Calculate the mean star rating
hhcaps_filtered['Star Rating for how patients rated overall care from agency'].mean()
# Out:
# 3.6925207756232687

# %%
answers['40.5'] = "3.69"

# %% [markdown]
# ---
#
# Checking Your Work
# ---
#
# After completing your work above and running each cell, you can check your answers by running the code below.
#
# The easiest way to do this is to use the `Kernel` -> `Restart Kernel and Run All Cells` menu option. This option restarts Python and runs every cell from top to bottom until it encounters an exception of some kind.  It will stop after running the cell below and outputing a summary of how many answers you have correct or incorrect.

# %%
import getpass
import boto3
import json

test = {
    "user": getpass.getuser(),
    "week": "week13",
    "answers": answers
}

client = boto3.client('lambda')

response = client.invoke(
    FunctionName="hds5210",
    InvocationType="RequestResponse",
    Payload=json.dumps(test))

result = json.loads(response['Payload'].read().decode('utf-8'))
# print(result)

try:
    print('{0:>5}{1:>20}{2:>10}'.format('Q#','Yours','Correct?'))
    for row in result.get('results'):
        print('{0:>5}{1:>20}{2:>10}'.format(str(row[0]),str(row[1]),str(row[2])))
except:
    print(result)
# Out:
#    Q#               Yours  Correct?
#  40.1                  39        OK
#  40.2                  55        OK
#  40.3                  TX        OK
#  40.4                  ME        OK
#  40.5                3.69        OK

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week13_assignment_1.ipynb
    # !git commit -a -m "Submitting the week 13 review exercises"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
# Out:
# Are you ready to submit your work?
# 1. Click the Save icon (or do Ctrl-S / Cmd-S)
# 2. Type "yes" or "no" below
# 3. Press Enter
#
# OK. We can wait.
